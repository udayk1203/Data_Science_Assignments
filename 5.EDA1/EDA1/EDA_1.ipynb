# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Setting Seaborn style
sns.set(style="whitegrid")

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS ON A DATASET**

# %% [markdown]
# ## **Objective:**
#
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.

# %% [markdown]
# ## **1.Data Cleaning and Preparation:**

# %%
df = pd.read_csv("/content/Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# ## Handle missing values

# %%
df.fillna(df.mean(), inplace=True) # Impute missing values with mean

# %% [markdown]
# ## **2.Statistical Summary:**

# %%
print(df.describe())
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# ## **3.Data Visualization:**

# %% [markdown]
# ## Histograms

# %%
df.hist(figsize=(14, 12), bins=20)
plt.suptitle('Histograms of Numerical Variables')
plt.show()

# %% [markdown]
# ## Boxplots

# %%
plt.figure(figsize=(14, 12))
sns.boxplot(data=df)
plt.title('Boxplots of Numerical Variables')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Scatter plot matrix or Pair plot

# %%
sns.pairplot(df)
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12, 10))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## **4.Pattern Recognition and Insights**

# %% [markdown]
# Identify correlations between variables and discuss their implications
#
# For example, check correlations between FHR and other variables to understand their relationship

# %%
correlations = df.corr()
print(correlations)
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.009433  0.072012 -0.093507 -0.033623
# FM        0.018777  0.009433  1.000000 -0.053226  0.009718  0.029901
# UC       -0.166570  0.072012 -0.053226  1.000000  0.190128 -0.006937
# DL       -0.126959 -0.093507  0.009718  0.190128  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.231103 -0.032691 -0.181161 -0.069361  0.008452
# MSTV     -0.170473  0.134168  0.017055  0.189406  0.410102  0.016163
# ALTV      0.210728 -0.271390 -0.011936 -0.227304 -0.186967 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %% [markdown]
# ## **Discussing potential implications**
# ### For example, if LB (Baseline FHR) has a high correlation with AC (Accelerations),
# ### it might suggest a relationship between fetal baseline heart rate and accelerations.

# %% [markdown]
# ## **5.Conclusion:**

# %% [markdown]
# ## **Summary of Key Insights**
# - Provide a summary of the main findings from the statistical summary and visualizations.
# - Discuss any notable correlations and their potential implications for fetal well-being.
# - Highlight any detected outliers and their possible impact on the data analysis.

# %% [markdown]
# ## **Recommendations**
# - Suggest further analysis or actions based on the findings.
# - Discuss how these insights could be used for decision-making in medical contexts or guide future studies.
